# %%
from scipy import stats
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('penambangandata.csv')
df
# Out:
#      NOMOR ANTRIAN  PENYAKIT JANTUNG  PENYAKIT HATI  PENYAKIT GINJAL  \
# 0             1001                66             88               64
# 1             1002                61            100               79
# 2             1003                58             53               98
# 3             1004                84             85               90
# 4             1005                56             77               70
# 5             1006                83             64               95
# 6             1007                81             84               62
# 7             1008                64             73               68
# 8             1009                75             73               58
# 9             1010                53             93               62
# 10            1011                51             79               72
# 11            1012               100             73               65
# 12            1013                65             59               78
# 13            1014                75             67               78
# 14            1015                51             77               91
# 15            1016                53             52               88
# 16            1017                63             55               52
# 17            1018                71             54               88
# 18            1019                97             52               98
# 19            1020                89             51               59
# 20            1021                79             96               85
# 21            1022                65             81               67
# 22            1023                97             62               62
# 23            1024                51             61               79
# 24            1025                81             62               83
# 25            1026                85             93               84
# 26            1027                66             89               94
# 27            1028                95             66               82
# 28            1029                56             68               77
# 29            1030                84             93               57
# ..             ...               ...            ...              ...
# 471           1472                89             67               51
# 472           1473                74             92               50
# 473           1474                95            100               55
# 474           1475                87             63               83
# 475           1476                74             88               92
# 476           1477                68             94               71
# 477           1478                72             79               95
# 478           1479                98             58               75
# 479           1480                90             96               56
# 480           1481                56             54               54
# 481           1482                80             54               77
# 482           1483                61             77               79
# 483           1484                91             69               52
# 484           1485                64             52               86
# 485           1486                73             75               68
# 486           1487                74             62               81
# 487           1488                76             59               60
# 488           1489                64             80              100
# 489           1490                63             94               54
# 490           1491                65             96               81
# 491           1492                63             68               92
# 492           1493                73             66               64
# 493           1494                54             57               98
# 494           1495                99             86               92
# 495           1496                79             93               62
# 496           1497                56             85               82
# 497           1498                81             66               69
# 498           1499                65             75               84
# 499           1500                79             97               85
# 500           1500                86             98               75
#
#      PENYAKIT MATA
# 0               69
# 1               68
# 2               65
# 3               77
# 4               88
# 5               81
# 6               99
# 7               99
# 8               76
# 9               82
# 10              76
# 11              82
# 12              98
# 13              58
# 14              71
# 15              68
# 16              87
# 17              59
# 18              77
# 19              92
# 20              86
# 21              73
# 22              57
# 23              64
# 24              69
# 25              93
# 26              89
# 27              70
# 28              61
# 29              80
# ..             ...
# 471             53
# 472             78
# 473             64
# 474             50
# 475             98
# 476             53
# 477             84
# 478             50
# 479             75
# 480             93
# 481             61
# 482             98
# 483             97
# 484             95
# 485             83
# 486             60
# 487             73
# 488             94
# 489             70
# 490             69
# 491             59
# 492             94
# 493             66
# 494             99
# 495             51
# 496             57
# 497             91
# 498             51
# 499             84
# 500             65
#
# [501 rows x 5 columns]

# %%
from IPython.display import HTML, display
import tabulate
table=[
    ["method"]+[x for x in df.columns],
    ["describe()"]+['<pre>'+str(df[col].describe())+'</pre>' for col in df.columns],
    ["count()"]+[df[col].count() for col in df.columns],
    ["mean()"]+[df[col].mean() for col in df.columns],
    ["std()"]+["{:.2f}".format(df[col].std()) for col in df.columns],
    ["min()"]+[df[col].min() for col in df.columns],
    ["max()"]+[df[col].max() for col in df.columns],
    ["q1()"]+[df[col].quantile(0.25) for col in df.columns],
    ["q2()"]+[df[col].quantile(0.50) for col in df.columns],
    ["q3()"]+[df[col].quantile(0.75) for col in df.columns],
    ["skew()"]+["{:.2f}".format(df[col].skew()) for col in df.columns],
]

display(HTML(tabulate.tabulate(table, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>method    </td><td>NOMOR ANTRIAN    </td><td>PENYAKIT JANTUNG </td><td>PENYAKIT HATI    </td><td>PENYAKIT GINJAL  </td><td>PENYAKIT MATA    </td></tr>
# <tr><td>describe()</td><td><pre>count     501.000000
# mean     1250.998004
# std       144.767061
# min      1001.000000
# 25%      1126.000000
# 50%      1251.000000
# 75%      1376.000000
# max      1500.000000
# Name: NOMOR ANTRIAN, dtype: float64</pre>                  </td><td><pre>count    501.000000
# mean      73.778443
# std       15.027868
# min       50.000000
# 25%       61.000000
# 50%       72.000000
# 75%       86.000000
# max      100.000000
# Name: PENYAKIT JANTUNG, dtype: float64</pre>                  </td><td><pre>count    501.000000
# mean      75.107784
# std       14.861371
# min       50.000000
# 25%       61.000000
# 50%       76.000000
# 75%       88.000000
# max      100.000000
# Name: PENYAKIT HATI, dtype: float64</pre>                  </td><td><pre>count    501.000000
# mean      75.920160
# std       14.887633
# min       50.000000
# 25%       63.000000
# 50%       77.000000
# 75%       88.000000
# max      100.000000
# Name: PENYAKIT GINJAL, dtype: float64</pre>                  </td><td><pre>count    501.000000
# mean      74.169661
# std       14.789089
# min       50.000000
# 25%       61.000000
# 50%       72.000000
# 75%       88.000000
# max      100.000000
# Name: PENYAKIT MATA, dtype: float64</pre>                  </td></tr>
# <tr><td>count()   </td><td>501              </td><td>501              </td><td>501              </td><td>501              </td><td>501              </td></tr>
# <tr><td>mean()    </td><td>1250.998003992016</td><td>73.77844311377245</td><td>75.10778443113773</td><td>75.92015968063872</td><td>74.16966067864271</td></tr>
# <tr><td>std()     </td><td>144.77           </td><td>15.03            </td><td>14.86            </td><td>14.89            </td><td>14.79            </td></tr>
# <tr><td>min()     </td><td>1001             </td><td>50               </td><td>50               </td><td>50               </td><td>50               </td></tr>
# <tr><td>max()     </td><td>1500             </td><td>100              </td><td>100              </td><td>100              </td><td>100              </td></tr>
# <tr><td>q1()      </td><td>1126.0           </td><td>61.0             </td><td>61.0             </td><td>63.0             </td><td>61.0             </td></tr>
# <tr><td>q2()      </td><td>1251.0           </td><td>72.0             </td><td>76.0             </td><td>77.0             </td><td>72.0             </td></tr>
# <tr><td>q3()      </td><td>1376.0           </td><td>86.0             </td><td>88.0             </td><td>88.0             </td><td>88.0             </td></tr>
# <tr><td>skew()    </td><td>-0.00            </td><td>0.18             </td><td>-0.05            </td><td>-0.06            </td><td>0.12             </td></tr>
# </tbody>
# </table>
